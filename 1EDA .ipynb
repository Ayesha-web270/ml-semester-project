# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\ST\Downloads\1Sleep_health_and_lifestyle_dataset.csv')

# %%
df.shape
# Out:
# (374, 13)

# %%
df.tail()
# Out:
#      Person ID  Gender   Age Occupation  Sleep Duration  Quality of Sleep  \
# 369        370  Female  59.0      Nurse             8.1               9.0
# 370        371  Female  59.0      Nurse             8.0               9.0
# 371        372  Female  59.0      Nurse             8.1               9.0
# 372        373  Female  59.0      Nurse             8.1               9.0
# 373        374  Female  59.0      Nurse             8.1               9.0
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 369                     75.0             3   Overweight         140/95
# 370                     75.0             3   Overweight         140/95
# 371                     75.0             3   Overweight         140/95
# 372                     75.0             3   Overweight         140/95
# 373                     75.0             3   Overweight         140/95
#
#      Heart Rate  Daily Steps Sleep Disorder
# 369        68.0         7000    Sleep Apnea
# ...

# %%
df.dtypes
# Out:
# Person ID                    int64
# Gender                      object
# Age                        float64
# Occupation                  object
# Sleep Duration             float64
# Quality of Sleep           float64
# Physical Activity Level    float64
# Stress Level                 int64
# BMI Category                object
# Blood Pressure              object
# Heart Rate                 float64
# Daily Steps                  int64
# Sleep Disorder              object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Person ID                    0
# Gender                       3
# Age                          3
# Occupation                   3
# Sleep Duration               0
# Quality of Sleep             1
# Physical Activity Level      1
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64

# %%
df.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  371.000000      374.000000        373.000000
# mean   187.500000   42.385445        7.132086          7.310992
# std    108.108742    8.911863        0.795657          1.198033
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   36.000000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   71.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               373.000000    374.000000  374.000000    374.000000
# mean                 59.396783      5.385027   69.965241   6816.844920
# std                  21.057351      1.774526    3.567258   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
df1 = df.select_dtypes(exclude='object')

# %%
# df1.corr()['Survived']
df1.corr()
# Out:
#                          Person ID       Age  Sleep Duration  \
# Person ID                 1.000000  0.941239        0.296305
# Age                       0.941239  1.000000        0.351880
# Sleep Duration            0.296305  0.351880        1.000000
# Quality of Sleep          0.433551  0.469071        0.883481
# Physical Activity Level   0.139563  0.169770        0.210980
# Stress Level             -0.394287 -0.415090       -0.811023
# Heart Rate               -0.229885 -0.225246       -0.579284
# Daily Steps               0.043844  0.066104       -0.039533
#
#                          Quality of Sleep  Physical Activity Level  \
# Person ID                        0.433551                 0.139563
# Age                              0.469071                 0.169770
# Sleep Duration                   0.883481                 0.210980
# Quality of Sleep                 1.000000                 0.184031
# Physical Activity Level          0.184031                 1.000000
# ...

# %%
print(df.columns)
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='Sleep Disorder', data=df)
# Out:
# <Axes: xlabel='Sleep Disorder', ylabel='count'>

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.distplot(df['Age'],hist=True)
# Out:
# C:\Users\ST\AppData\Local\Temp\ipykernel_7052\950244213.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],hist=True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(df['Daily Steps'])
# Out:
# <Axes: ylabel='Daily Steps'>

# %%
sns.distplot(df['Daily Steps'],hist=True)
# Out:
# C:\Users\ST\AppData\Local\Temp\ipykernel_7052\1907813009.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Daily Steps'],hist=True)
# <Axes: xlabel='Daily Steps', ylabel='Density'>

# %%
sns.boxplot(df['Stress Level'])
# Out:
# <Axes: ylabel='Stress Level'>

# %%
sns.distplot(df['Stress Level'],hist=True)
# Out:
# C:\Users\ST\AppData\Local\Temp\ipykernel_7052\2471804920.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Stress Level'],hist=True)
# <Axes: xlabel='Stress Level', ylabel='Density'>

# %%
sns.boxplot(df['Heart Rate'])
# Out:
# <Axes: ylabel='Heart Rate'>

# %%
sns.distplot(df['Heart Rate'],hist=True)
# Out:
# C:\Users\ST\AppData\Local\Temp\ipykernel_7052\63949710.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Heart Rate'],hist=True)
# <Axes: xlabel='Heart Rate', ylabel='Density'>

# %%
sns.boxplot(df['Physical Activity Level'])
# Out:
# <Axes: ylabel='Physical Activity Level'>

# %%
sns.distplot(df['Physical Activity Level'],hist=True)
# Out:
# C:\Users\ST\AppData\Local\Temp\ipykernel_7052\4180185934.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Physical Activity Level'],hist=True)
# <Axes: xlabel='Physical Activity Level', ylabel='Density'>

# %%
sns.boxplot(df['Quality of Sleep'])
# Out:
# <Axes: ylabel='Quality of Sleep'>

# %%
sns.distplot(df['Quality of Sleep'],hist=True)
# Out:
# C:\Users\ST\AppData\Local\Temp\ipykernel_7052\1197111034.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Quality of Sleep'],hist=True)
# <Axes: xlabel='Quality of Sleep', ylabel='Density'>

# %%
sns.boxplot(df['Sleep Duration'])
# Out:
# <Axes: ylabel='Sleep Duration'>

# %%
sns.distplot(df['Sleep Duration'],hist=True)
# Out:
# C:\Users\ST\AppData\Local\Temp\ipykernel_7052\4285713854.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Sleep Duration'],hist=True)
# <Axes: xlabel='Sleep Duration', ylabel='Density'>

# %%
df[['Systolic_BP', 'Diastolic_BP']] = df['Blood Pressure'].str.split('/', expand=True).astype(float)

# %%
sns.boxplot(df['Blood Pressure'])
# Out:
# <Axes: ylabel='Blood Pressure'>

# %%
sns.histplot(df['Systolic_BP'], kde=True, bins=20)
plt.title('Distribution of Systolic Blood Pressure')
plt.show()

# %%
sns.histplot(df['Diastolic_BP'], kde=True, bins=20)
plt.title('Distribution of Diastolic Blood Pressure')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   371 non-null    object
#  2   Age                      371 non-null    float64
#  3   Occupation               371 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         373 non-null    float64
#  6   Physical Activity Level  373 non-null    float64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    float64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
#  13  Systolic_BP              374 non-null    float64
# ...
